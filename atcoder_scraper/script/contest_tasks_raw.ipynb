# %%
from pymongo import MongoClient
from datetime import datetime

import os
import requests
import time

mongo_connection_uri = os.environ.get("ME_CONFIG_MONGODB_URL")
client = MongoClient(mongo_connection_uri)

db = client["atcoder"]
contest_collection = db["contest"]
contest_tasks_raw_collection = db["contest_tasks_raw"]

# %%
def get_html(contest_url):
    url = f"https://atcoder.jp/{contest_url}/tasks"
    cookies = {
        "_ga": "GA1.1.1669735030.1727884004",
        "REVEL_FLASH": "",
        "timeDelta": "1789",
        "REVEL_SESSION": "fc485232f64d6bfd00e592aa6bea1a972f6930a5-%00SessionKey%3Af712625f246d5b11787eeeac74b6cefd3f43ebfeb6e05e5a6b9568a08ba4367cebdfbc32acea8a-0b0fdeaa544c89f44b7326075ad509e6ba62c1c71fa969e5d0cab3c4e61ee30d%00%00UserScreenName%3Adarcy_zhang%00%00csrf_token%3AiecE%2FCD%2BWkZctrj%2BaFUUE0TovINExsqeelroJ6VJx9Q%3D%00%00_TS%3A1746183164%00%00UserName%3Adarcy_zhang%00%00a%3Afalse%00%00w%3Afalse%00",
        "_ga_RC512FD18N": "GS1.1.1730628353.9.1.1730631162.0.0.0",
    }

    headers = {
        "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
        "accept-language": "en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7,en-GB;q=0.6,zh-TW;q=0.5",
        "cache-control": "no-cache",
        "pragma": "no-cache",
        "priority": "u=0, i",
        "sec-ch-ua": '"Chromium";v="130", "Microsoft Edge";v="130", "Not?A_Brand";v="99"',
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": '"Windows"',
        "sec-fetch-dest": "document",
        "sec-fetch-mode": "navigate",
        "sec-fetch-site": "none",
        "sec-fetch-user": "?1",
        "upgrade-insecure-requests": "1",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36 Edg/130.0.0.0",
    }

    response = requests.get(url, cookies=cookies, headers=headers)
    response.encoding = 'utf-8'
    return response.text

# %%
for contest_item in contest_collection.find():
    start_time = datetime.strptime(contest_item["start_time"], "%Y-%m-%d %H:%M:%S%z")
    cutoff_date = datetime(2021, 9, 1, tzinfo=start_time.tzinfo)
    # if start_time > cutoff_date:
    if start_time <= cutoff_date:
        time.sleep(0.3)
        contest_url = contest_item["contest_url"]
        print(contest_url)
        raw_html = get_html(contest_url)
        contest_tasks_raw_collection.insert_one({
            "raw_html": raw_html
        })
# Out:
# /contests/abc216
# /contests/arc125
# /contests/abc215
# /contests/abc214
# /contests/abc213
# /contests/ahc005
# /contests/abc212
# /contests/arc124
# /contests/abc211
# /contests/arc123
# /contests/abc210
# /contests/abc209
# /contests/abc208
# /contests/agc054
# /contests/abc207
# /contests/ahc004
# /contests/abc206
# /contests/abc205
# /contests/arc122
# /contests/abc204
# /contests/abc203
# /contests/arc121
# /contests/arc120
# /contests/abc202
# /contests/ahc003
# /contests/arc119
# /contests/abc201
# /contests/arc118
# /contests/abc200
# /contests/zone2021
# /contests/ahc002
# /contests/abc199
# /contests/arc117
# /contests/jsc2021
# /contests/abc198
# /contests/agc053
# /contests/arc116
# /contests/abc197
# /contests/arc115
# /contests/abc196
# /contests/arc114
# /contests/abc195
# /contests/agc052
# /contests/abc194
# /contests/ahc001
# /contests/abc193
# /contests/arc113
# /contests/abc192
# /contests/arc112
# /contests/abc191
# /contests/abc190
# /contests/abc189
# ...
