# %%
import requests

cookies = {
    '_ga': 'GA1.1.1669735030.1727884004',
    'REVEL_FLASH': '',
    'timeDelta': '1789',
    'REVEL_SESSION': '2a5fc9cbf66a1b5f236e3bdce883834d4eb7e446-%00csrf_token%3AiecE%2FCD%2BWkZctrj%2BaFUUE0TovINExsqeelroJ6VJx9Q%3D%00%00_TS%3A1746183665%00%00UserName%3Adarcy_zhang%00%00a%3Afalse%00%00w%3Afalse%00%00SessionKey%3Af712625f246d5b11787eeeac74b6cefd3f43ebfeb6e05e5a6b9568a08ba4367cebdfbc32acea8a-0b0fdeaa544c89f44b7326075ad509e6ba62c1c71fa969e5d0cab3c4e61ee30d%00%00UserScreenName%3Adarcy_zhang%00',
    '_ga_RC512FD18N': 'GS1.1.1730628353.9.1.1730631662.0.0.0',
}

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7,en-GB;q=0.6,zh-TW;q=0.5',
    'cache-control': 'no-cache',
    'pragma': 'no-cache',
    'priority': 'u=0, i',
    'referer': 'https://atcoder.jp/contests/abc378/submissions?f.Task=abc378_a&f.LanguageName=Python&f.Status=AC&f.User=',
    'sec-ch-ua': '"Chromium";v="130", "Microsoft Edge";v="130", "Not?A_Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36 Edg/130.0.0.0',
}

response = requests.get('https://atcoder.jp/contests/abc378/submissions/59420075', cookies=cookies, headers=headers)
print(response.text)

# %%
from datetime import datetime

# 给定的时间字符串
start_time_str = "2024-10-26 21:00:00+0900"

# 将时间字符串解析为 datetime 对象
# 注意：由于时间字符串中包含时区偏移信息，我们需要特别处理
start_time = datetime.strptime(start_time_str, "%Y-%m-%d %H:%M:%S%z")

# 定义2021年9月1日的 datetime 对象（假设无时区）
cutoff_date = datetime(2021, 9, 1, tzinfo=start_time.tzinfo)  # 利用 start_time 的时区信息

# 比较日期时间，判断是否在2021年9月1日之后
if start_time > cutoff_date:
    print("保留该时间：", start_time_str)
else:
    print("丢弃该时间：", start_time_str)

# %%
import requests

cookies = {
    "_ga": "GA1.1.1669735030.1727884004",
    "REVEL_FLASH": "",
    "timeDelta": "1798",
    "REVEL_SESSION": "7ef009ac84abdaa342099f8949d4424be0a70f21-%00csrf_token%3AiecE%2FCD%2BWkZctrj%2BaFUUE0TovINExsqeelroJ6VJx9Q%3D%00%00_TS%3A1746186078%00%00UserName%3Adarcy_zhang%00%00a%3Afalse%00%00w%3Afalse%00%00SessionKey%3Af712625f246d5b11787eeeac74b6cefd3f43ebfeb6e05e5a6b9568a08ba4367cebdfbc32acea8a-0b0fdeaa544c89f44b7326075ad509e6ba62c1c71fa969e5d0cab3c4e61ee30d%00%00UserScreenName%3Adarcy_zhang%00",
    "_ga_RC512FD18N": "GS1.1.1730628353.9.1.1730634089.0.0.0",
}

headers = {
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "accept-language": "en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7,en-GB;q=0.6,zh-TW;q=0.5",
    "cache-control": "no-cache",
    "pragma": "no-cache",
    "priority": "u=0, i",
    "referer": "https://atcoder.jp/contests/abc378/submissions?f.Task=abc378_a&f.LanguageName=Brainfuck&f.Status=&f.User=",
    "sec-ch-ua": '"Chromium";v="130", "Microsoft Edge";v="130", "Not?A_Brand";v="99"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "document",
    "sec-fetch-mode": "navigate",
    "sec-fetch-site": "same-origin",
    "sec-fetch-user": "?1",
    "upgrade-insecure-requests": "1",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36 Edg/130.0.0.0",
}

params = {
    "f.Task": "abc378_a",
    "f.LanguageName": "Python",
    "f.Status": "AC",
    "f.User": "",
}

response = requests.get(
    "https://atcoder.jp/contests/abc378/submissions",
    params=params,
    cookies=cookies,
    headers=headers,
)

# %%
print(response.text)

# %%
import requests

cookies = {
    "_ga": "GA1.1.1669735030.1727884004",
    "REVEL_FLASH": "",
    "timeDelta": "2007",
    "REVEL_SESSION": "8ed0689f1af1fa89bab4edd30927ff7273e1ad0e-%00csrf_token%3AiecE%2FCD%2BWkZctrj%2BaFUUE0TovINExsqeelroJ6VJx9Q%3D%00%00_TS%3A1746190748%00%00UserName%3Adarcy_zhang%00%00a%3Afalse%00%00w%3Afalse%00%00SessionKey%3Af712625f246d5b11787eeeac74b6cefd3f43ebfeb6e05e5a6b9568a08ba4367cebdfbc32acea8a-0b0fdeaa544c89f44b7326075ad509e6ba62c1c71fa969e5d0cab3c4e61ee30d%00%00UserScreenName%3Adarcy_zhang%00",
    "_ga_RC512FD18N": "GS1.1.1730638744.10.1.1730638745.0.0.0",
}

headers = {
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "accept-language": "en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7,en-GB;q=0.6,zh-TW;q=0.5",
    "cache-control": "no-cache",
    "pragma": "no-cache",
    "priority": "u=0, i",
    "referer": "https://atcoder.jp/contests/abc378/submissions?f.Task=abc378_a&f.LanguageName=Python&f.Status=AC&f.User=",
    "sec-ch-ua": '"Chromium";v="130", "Microsoft Edge";v="130", "Not?A_Brand";v="99"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "document",
    "sec-fetch-mode": "navigate",
    "sec-fetch-site": "same-origin",
    "sec-fetch-user": "?1",
    "upgrade-insecure-requests": "1",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36 Edg/130.0.0.0",
}

response = requests.get(
    "https://atcoder.jp/contests/abc378/submissions/59421258",
    cookies=cookies,
    headers=headers,
)
